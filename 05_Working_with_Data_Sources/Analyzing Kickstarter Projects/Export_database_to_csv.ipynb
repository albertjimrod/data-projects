# %% [markdown]
# ## Export database to csv

# %% [markdown]
# <img src="png/SQLite.png" alt="drawing" width="500"/>

# %% [markdown]
# One way to **dump a database in sqlite3 to csv**.
#
#
# Simply as an exercise and a utility.

# %%
import sqlite3
import csv
import pandas as pd

# Conectar a la base de datos SQLite
conn = sqlite3.connect('database/ksprojects.db')  # Reemplaza 'tudatabase.db' con el nombre de tu base de datos SQLite
cursor = conn.cursor()

# Ejecutar una consulta SQL para seleccionar datos de la tabla
cursor.execute("SELECT * FROM ksprojects")  # Reemplaza 'nombre_de_la_tabla' con el nombre de tu tabla

# Obtener los resultados de la consulta
rows = cursor.fetchall()

# Cerrar la conexión a la base de datos
conn.close()

# Escribir los datos en un archivo CSV
with open('ksprojects_datos_exportados.csv', 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Escribir el encabezado (nombres de las columnas)
    column_names = [description[0] for description in cursor.description]
    csv_writer.writerow(column_names)
    
    # Escribir los datos
    csv_writer.writerows(rows)

print("Exportación completada. Los datos se han guardado en 'ksprojects_datos_exportados.csv'.")
# Out:
# Exportación completada. Los datos se han guardado en 'datos_exportados.csv'.

# %%
df = pd.read_csv("ksprojects_datos_exportados.csv")

# %%
df.head(10)
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
# 5  1000014025                               Monarch Espresso Bar
# 6  1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7  1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8  1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9   100004195  STUDIO IN THE SKY - A Documentary Feature Film...
#
#          category main_category      goal   pledged       state  backers
# 0          Poetry    Publishing    1000.0      0.00      failed        0
# 1  Narrative Film  Film & Video   30000.0   2421.00      failed       15
# 2  Narrative Film  Film & Video   45000.0    220.00      failed        3
# 3           Music         Music    5000.0      1.00      failed        1
# 4    Film & Video  Film & Video   19500.0   1283.00    canceled       14
# 5     Restaurants          Food   50000.0  52375.00  successful      224
# 6            Food          Food    1000.0   1205.00  successful       16
# 7          Drinks          Food   25000.0    453.00      failed       40
# 8  Product Design        Design  125000.0   8233.00    canceled       58
# 9     Documentary  Film & Video   65000.0   6240.57    canceled       43
